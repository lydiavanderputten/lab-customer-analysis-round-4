# %%
import pandas as pd

# %%
file1=pd.read_csv('files_for_lab/csv_files/marketing_customer_analysis.csv')

# %%
file1.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
file1
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
file1.shape
# Out:
# (10910, 26)

# %%
cols1=[]
for c in file1.columns:
    cols1.append(c.lower())
file1.columns=cols1

# %%
file1.dtypes
file1
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
file1._get_numeric_data()
# Out:
#        unnamed: 0  customer lifetime value  income  monthly premium auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months since last claim  months since policy inception  \
# ...

# %%
file1.isna().sum()
# Out:
# unnamed: 0                          0
# customer                            0
# state                             631
# customer lifetime value             0
# response                          631
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           633
# months since policy inception       0
# number of open complaints         633
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# ...

# %%
#I decided to drop the columns with a lot (the most) NaN values 
file1 = file1.drop('vehicle type', axis=1) 
# “axis 1” represents columns
# find mode for categorical data columns (state)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-8c75c477b8c7> in <module>
#       1 #I decided to drop the columns with a lot (the most) NaN values
# ----> 2 file1 = file1.drop('vehicle type', axis=1)
#       3 # “axis 1” represents columns
#       4 # find mode for categorical data columns (state)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# ...

# %%
file1.columns
# Out:
# Index(['unnamed: 0', 'customer', 'state', 'customer lifetime value',
#        'response', 'coverage', 'education', 'effective to date',
#        'employmentstatus', 'gender', 'income', 'location code',
#        'marital status', 'monthly premium auto', 'months since last claim',
#        'months since policy inception', 'number of open complaints',
#        'number of policies', 'policy type', 'policy', 'renew offer type',
#        'sales channel', 'total claim amount', 'vehicle class', 'vehicle size',
#        'month'],
#       dtype='object')

# %%
import numpy as np

# %%
# impute a value for the missing value (fill in a value that we choose or calculate)
# months since last claim
mean_months_lastclaim = np.mean(file1['months since last claim'].mean()
file1['months since last claim'] = file1['months since last claim'].fillna(months since last claim)
# I cant solve how to fix this
# Out:
#   File "<ipython-input-55-1562f4d06d97>", line 4
#     file1['months since last claim'] = file1['months since last claim'].fillna(months since last claim)
#     ^
# SyntaxError: invalid syntax

# %%
# number of open complaints
mean_open_complaints = np.mean(file1)['number of open claims'].mean()
file1['number of open claims'] = file1['number of open claims'].fillna(number of open claims)
# I cant solve how to fix this
# Out:
#   File "<ipython-input-56-0bbb4dafe7aa>", line 3
#     file1['number of open claims'] = file1['number of open claims'].fillna(number of open claims)
#                                                                                   ^
# SyntaxError: invalid syntax

# %%
file1['effective to date'] = pd.to_datetime(file1['effective to date'])

# %%
file1['month'] = file1['effective to date'].dt.month

# %%
file1
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
file1['month']==1,2,3].dt.month
# I cant solve how to specify the months --> 1,2,3 is not correct
# Out:
#   File "<ipython-input-54-63ee6ea1bfe8>", line 1
#     file1['month']==1,2,3].dt.month
#                          ^
# SyntaxError: unmatched ']'

# %%
#this is the end of lab customer analysis round 2

# %%
file1.dtypes
file1
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
file1.head(10)
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
# 5           5  HO81102         NaN              4745.181764      NaN
# 6           6  IW72280  California              5035.035257       No
# 7           7  IH64929  California              4956.247235       No
# 8           8  FM55990  California              5989.773931      Yes
# 9           9  QX31376      Oregon             17114.328150       No
#
#    Coverage             Education Effective To Date EmploymentStatus Gender  \
# 0     Basic               College           2/18/11         Employed      M
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Show a plot of the total number of responses.
sns.countplot(file1['Response'])
plt.show()
# Out:
# C:\Users\lydia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Show a plot of the response rate by the sales channel.
sns.countplot(x='Sales Channel', hue='Response', data=file1)
plt.show()

# %%
# Show a plot of the response rate by the total claim amount
sns.barplot(x='Response', y='Total Claim Amount', data=file1)
plt.show()

# %%
# Show a plot of the response rate by income
sns.barplot(x='Response', y='Income', data=file1)
plt.show()

# %%
#start with Lab | Customer Analysis Round 4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file1.head(10)
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
# 5           5  HO81102         NaN              4745.181764      NaN
# 6           6  IW72280  California              5035.035257       No
# 7           7  IH64929  California              4956.247235       No
# 8           8  FM55990  California              5989.773931      Yes
# 9           9  QX31376      Oregon             17114.328150       No
#
#    Coverage             Education Effective To Date EmploymentStatus Gender  \
# 0     Basic               College           2/18/11         Employed      M
# ...

# %%
#Check the data types of the columns. Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categoricals. (You can use np.number and np.object to select the numerical data types and categorical data types respectively)

# %%
file1.dtypes
# Out:
# Unnamed: 0                         int64
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim          float64
# Months Since Policy Inception      int64
# Number of Open Complaints        float64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# ...

# %%
numerical = file1.select_dtypes(include = ['int64', 'float64']) 
categorical = file1.select_dtypes(include = ['object'])

# %%
numericals = file1._get_numeric_data()

# %%
numericals
# Out:
#        Unnamed: 0  Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# ...

# %%
categoricals = file1.select_dtypes('object')

# %%
categoricals
# Out:
#       Customer       State Response  Coverage Education Effective To Date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# ...

# %%
type(categorical)
# Out:
# pandas.core.frame.DataFrame

# %%
type(numerical)
# Out:
# pandas.core.frame.DataFrame

# %%
#Now we will try to check the normality of the numerical variables visually

# %%
sns.displot(x=numericals['Income'])
plt.show()

# %%
# note Erin --> to see the graph above without all of the 0s for income

# %%
sns.displot(x=numericals['Total Claim Amount'])
plt.show()

# %%
sns.displot(x=numericals['Customer Lifetime Value'])
plt.show()

# %%
#Use Matplotlib to construct histograms

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(x=numericals['Income'])
plt.show()

# %%
plt.hist(x=numericals['Total Claim Amount'])
plt.show()

# %%
plt.hist(x=numericals['Customer Lifetime Value'])
plt.show()

# %%
#Do the distributions for different numerical variables look like a normal distribution

# %%
numericals['Income'].describe()
# Out:
# count    10910.000000
# mean     37536.284785
# std      30359.195670
# min          0.000000
# 25%          0.000000
# 50%      33813.500000
# 75%      62250.750000
# max      99981.000000
# Name: Income, dtype: float64

# %%
iqr = np.percentile(numericals['Income'],75) - np.percentile(numericals['Income'],25)
upper_limit = np.percentile(numericals['Income'],75) + 1.5*iqr
lower_limit = np.percentile(numericals['Income'],25) - 1.5*iqr
data = numericals[(numericals['Income']>lower_limit) & (numericals['Income']<upper_limit)]
sns.displot(numericals['Income'])
plt.show()

# %%
# For the numerical variables, check the multicollinearity between the features. 
#Please note that we will use the column total_claim_amount later as the target variable.

# %%
#Target variabele = 'Total Claim Amount'

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
sns.scatterplot(x='Income',y='Customer Lifetime Value',data=file1)
plt.show()

# %%
from sklearn import linear_model

lm = linear_model.LinearRegression()

# %%
regression_line = lm.intercept_ + lm.coef_[0]*reg_data['Total Claim Amount']
plt.plot(reg_data['Total Claim Amount'], regression_line, c = 'orange')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-7cf63999db24> in <module>
# ----> 1 regression_line = lm.intercept_ + lm.coef_[0]*reg_data['Total Claim Amount']
#       2 plt.plot(reg_data['Total Claim Amount'], regression_line, c = 'orange')
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'

# %%
# Drop one of the two features that show a high correlation between them (greater than 0.9). 
# Write code for both the correlation matrix and for seaborn heatmap. If there is no pair of features that have a high correlation, then do not drop any features

# %%
correlations_matrix = numericals.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %%
reduced_data = file1.drop(['Customer Lifetime Value', 'Months Since Last Claim'],axis=1)
reduced_data.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Response', 'Coverage', 'Education',
#        'Effective To Date', 'EmploymentStatus', 'Gender', 'Income',
#        'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
#Start Lab customer 5

# %%
#Processing Data --> X-y split

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
y = file1['Total Claim Amount']
X = reduced_data.drop(['Total Claim Amount'], axis=1)
lm = linear_model.LinearRegression()
model = lm.fit(X,y)
lm.score(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-d3d453727e07> in <module>
#       4 X = reduced_data.drop(['Total Claim Amount'], axis=1)
#       5 lm = linear_model.LinearRegression()
# ----> 6 model = lm.fit(X,y)
#       7 lm.score(X,y)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# ...

# %%
#Processing Data --Normalize (numerical)

from sklearn.preprocessing import MinMaxScaler
MinMaxtransformer = MinMaxScaler().fit(file1)
x_normalized = MinMaxtransformer.transform(file1)
print(x_normalized.shape)
x_normalized = pd.file1(x_normalized,columns=file1.columns)
x_normalized.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-782a5a1cd3a3> in <module>
#       2
#       3 from sklearn.preprocessing import MinMaxScaler
# ----> 4 MinMaxtransformer = MinMaxScaler().fit(file1)
#       5 x_normalized = MinMaxtransformer.transform(file1)
#       6 print(x_normalized.shape)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     361         # Reset internal state before fitting
#     362         self._reset()
# --> 363         return self.partial_fit(X, y)
#     364
#     365     def partial_fit(self, X, y=None):
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y)
#     394
#     395         first_pass = not hasattr(self, 'n_samples_seen_')
# --> 396         X = self._validate_data(X, reset=first_pass,
# ...
